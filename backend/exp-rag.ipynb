# %%
pip install pinecone-client
# Out:
# Collecting pinecone-client
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (2024.7.4)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client)
#   Downloading pinecone_plugin_inference-1.0.3-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (1.26.18)
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading pinecone_plugin_inference-1.0.3-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 7.8 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone-plugin-inference, pinecone-client
# Successfully installed pinecone-client-5.0.1 pinecone-plugin-inference-1.0.3 pinecone-plugin-interface-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain
# -0.2.11
# Out:
# Collecting langchain
#   Downloading langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain)
#   Downloading langchain_core-0.2.39-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.117-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (1.33)
# Collecting packaging<25,>=23.2 (from langchain-core<0.3.0,>=0.2.38->langchain)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain) (2.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Downloading langchain-0.2.16-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.7 MB/s eta 0:00:0000:010:01
# Downloading langchain_core-0.2.39-py3-none-any.whl (396 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.6/396.6 kB 25.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.117-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 18.1 MB/s eta 0:00:00
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: packaging, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.4 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.2 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.4 requires shapely<2.1,>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pointpats 2.5.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spaghetti 1.7.6 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.1 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.9.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.0 which is incompatible.
# Successfully installed langchain-0.2.16 langchain-core-0.2.39 langchain-text-splitters-0.2.4 langsmith-0.1.117 packaging-24.1

# %%
# !pip install -U langchain-community
# 0.2.10
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.2.16-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (0.2.16)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (0.2.39)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (0.1.117)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.2.0)
# Downloading langchain_community-0.2.16-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: langchain-community
# Successfully installed langchain-community-0.2.16

# %%
# !pip install langchain_huggingface
# 0.0.3
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langchain_huggingface) (0.24.6)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /opt/conda/lib/python3.10/site-packages (from langchain_huggingface) (0.2.39)
# Collecting sentence-transformers>=2.6.0 (from langchain_huggingface)
#   Downloading sentence_transformers-3.1.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: tokenizers>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /opt/conda/lib/python3.10/site-packages (from langchain_huggingface) (4.44.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.1.117)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (8.3.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.4.0+cpu)
# Requirement already satisfied: numpy<2.0.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.14.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (9.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.4)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (3.10.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.7.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.2.0)
# Downloading langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Downloading sentence_transformers-3.1.0-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 5.5 MB/s eta 0:00:0000:01
# Installing collected packages: sentence-transformers, langchain_huggingface
# Successfully installed langchain_huggingface-0.0.3 sentence-transformers-3.1.0

# %%
# !pip install groq
# !pip install langchain_groq
# Out:
# Collecting groq
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from groq) (2.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/lib/python3.10/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (1.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (2.20.1)
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: groq
# Successfully installed groq-0.11.0
# Collecting langchain_groq
#   Downloading langchain_groq-0.1.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from langchain_groq) (0.11.0)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.26 in /opt/conda/lib/python3.10/site-packages (from langchain_groq) (0.2.39)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (2.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/lib/python3.10/site-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_groq) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_groq) (0.1.117)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.26->langchain_groq) (8.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (1.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.26->langchain_groq) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.26->langchain_groq) (3.10.4)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.26->langchain_groq) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.26->langchain_groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.26->langchain_groq) (1.26.18)
# Downloading langchain_groq-0.1.9-py3-none-any.whl (14 kB)
# Installing collected packages: langchain_groq
# Successfully installed langchain_groq-0.1.9

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from transformers import pipeline
import json
import pandas as pd

# %%
from langchain.docstore.document import Document
from langchain_huggingface import HuggingFaceEmbeddings
from pinecone import Pinecone, ServerlessSpec
from transformers import AutoModelForCausalLM, AutoTokenizer
from langchain import PromptTemplate, LLMChain
from langchain.chains import RetrievalQA
from langchain.vectorstores import Pinecone as PineconeVectorStore
from transformers import pipeline
from langchain.llms.base import LLM
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langchain.docstore.document import Document
# ----> 2 from langchain_huggingface import HuggingFaceEmbeddings
#       3 from pinecone import Pinecone, ServerlessSpec
#       4 from transformers import AutoModelForCausalLM, AutoTokenizer
#
# File d:\Anacondaa\lib\site-packages\langchain_huggingface\__init__.py:1
# ----> 1 from langchain_huggingface.chat_models import (
#       2     ChatHuggingFace,  # type: ignore[import-not-found]
#       3 )
#       4 from langchain_huggingface.embeddings import (
#       5     HuggingFaceEmbeddings,
#       6     HuggingFaceEndpointEmbeddings,
#       7 )
#       8 from langchain_huggingface.llms import (
#       9     HuggingFaceEndpoint,
#      10     HuggingFacePipeline,
#      11 )
#
# File d:\Anacondaa\lib\site-packages\langchain_huggingface\chat_models\__init__.py:1
# ----> 1 from langchain_huggingface.chat_models.huggingface import (  # type: ignore[import-not-found]
#       2     TGI_MESSAGE,
#       3     TGI_RESPONSE,
#       4     ChatHuggingFace,
#       5     _convert_message_to_chat_message,
#       6     _convert_TGI_message_to_LC_message,
#       7 )
#       9 __all__ = [
#      10     "ChatHuggingFace",
#      11     "_convert_message_to_chat_message",
#    (...)
#      14     "TGI_RESPONSE",
#      15 ]
#
# File d:\Anacondaa\lib\site-packages\langchain_huggingface\chat_models\huggingface.py:21
#       4 from typing import (
#       5     Any,
#       6     Callable,
#    (...)
#      14     cast,
#      15 )
#      17 from langchain_core.callbacks.manager import (
#      18     AsyncCallbackManagerForLLMRun,
#      19     CallbackManagerForLLMRun,
#      20 )
# ---> 21 from langchain_core.language_models import LanguageModelInput
#      22 from langchain_core.language_models.chat_models import BaseChatModel
#      23 from langchain_core.messages import (
#      24     AIMessage,
#      25     BaseMessage,
#    (...)
#      29     ToolMessage,
#      30 )
#
# File d:\Anacondaa\lib\site-packages\langchain_core\language_models\__init__.py:42
#       1 """**Language Model** is a type of model that can generate text or complete
#       2 text prompts.
#       3
#    (...)
#      39
#      40 """  # noqa: E501
# ---> 42 from langchain_core.language_models.base import (
#      43     BaseLanguageModel,
#      44     LangSmithParams,
#      45     LanguageModelInput,
#      46     LanguageModelLike,
#      47     LanguageModelOutput,
#      48     get_tokenizer,
#      49 )
#      50 from langchain_core.language_models.chat_models import BaseChatModel, SimpleChatModel
#      51 from langchain_core.language_models.fake import FakeListLLM, FakeStreamingListLLM
#
# File d:\Anacondaa\lib\site-packages\langchain_core\language_models\base.py:16
#       5 from functools import cache
#       6 from typing import (
#       7     TYPE_CHECKING,
#       8     Any,
#    (...)
#      13     Union,
#      14 )
# ---> 16 from pydantic import BaseModel, ConfigDict, Field, field_validator
#      17 from typing_extensions import TypeAlias, TypedDict, override
#      19 from langchain_core._api import deprecated
#
# ImportError: cannot import name 'field_validator' from 'pydantic' (d:\Anacondaa\lib\site-packages\pydantic\__init__.cp39-win_amd64.pyd)

# %%
from langchain.memory import ConversationBufferMemory

# %%
from langchain.vectorstores.base import VectorStoreRetriever
from langchain.schema import Document
from pydantic import Field
from typing import List

# %%
from nltk.tokenize import sent_tokenize
from langchain.docstore.document import Document

# %%
text = """The rapid advancements in artificial intelligence (AI) bring benefits and problems to user interface (UI) design. Human-Computer Interaction(HCI) concept has been a fundamental part of human and AI interaction for more than two decades given the advancement of AI and its growing applications in human-centric fields. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions. This thesis research discusses issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making, and addressing automation bias, which occurs when people over trust and blindly embrace computer-based assistance. The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX. Modern AI development tends to be technology-driven, therefore UX is not attended optimally. HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed. HCAI has lately surfaced as a trend however, there is still work to be done to reduce the remaining gap which is only possible by its widespread acceptance.The objective of the research was to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys. The findings of the paper investigate collaborative intelligence and ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.Keywords: Human-Computer Interaction, Artificial Intelligence, User Interface, User Experience, AI-driven Interfaces, Human-centered AI, Users, Pakistan"""

# %% [markdown]
# # Documents

# %%
sentences = sent_tokenize(text)

# Function to create chunks of sentences with overlap
def create_sentence_chunks(sentences, chunk_size, chunk_overlap):
    chunks = []
    
    # Create chunks with overlap
    for i in range(0, len(sentences), chunk_size - chunk_overlap):
        chunk = ' '.join(sentences[i:i + chunk_size])
        chunks.append(chunk)
        # Stop if we reach the end
        if i + chunk_size >= len(sentences):
            break
    
    return chunks

chunk_size = 3  
chunk_overlap = 1  

# chunks of sentences
sentence_chunks = create_sentence_chunks(sentences, chunk_size, chunk_overlap)

documents = [Document(page_content=chunk) for chunk in sentence_chunks]

# %%
for i, doc in enumerate(documents):
    print(f"Document {i+1}:\n{doc.page_content}\n")
# Out:
# Document 1:
# The rapid advancements in artificial intelligence (AI) bring benefits and problems to user interface (UI) design. Human-Computer Interaction(HCI) concept has been a fundamental part of human and AI interaction for more than two decades given the advancement of AI and its growing applications in human-centric fields. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions.
#
# Document 2:
# The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions. This thesis research discusses issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making, and addressing automation bias, which occurs when people over trust and blindly embrace computer-based assistance. The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.
#
# Document 3:
# The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX. Modern AI development tends to be technology-driven, therefore UX is not attended optimally. HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed.
#
# Document 4:
# HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed. HCAI has lately surfaced as a trend however, there is still work to be done to reduce the remaining gap which is only possible by its widespread acceptance.The objective of the research was to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys. The findings of the paper investigate collaborative intelligence and ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.Keywords: Human-Computer Interaction, Artificial Intelligence, User Interface, User Experience, AI-driven Interfaces, Human-centered AI, Users, Pakistan

# %% [markdown]
# # Text Embeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def pad_embedding(embedding, target_dim=512):
    # Convert to numpy array if it's not already
    if not isinstance(embedding, np.ndarray):
        embedding = np.array(embedding)
    
    # Calculate the padding needed
    current_dim = embedding.shape[-1]
    if current_dim < target_dim:
        padding = np.zeros(target_dim - current_dim)
        padded_embedding = np.concatenate([embedding, padding])
    else:
        padded_embedding = embedding
    
    return padded_embedding

# %%
def extract_embeddings(df):
    all_embeddings = []
    for text in df:
        # Extract the embedding
        embedding = embeddings.embed_query(text)
        # Pad the embedding to the desired length (512)
        padded_embedding = pad_embedding(embedding, target_dim=512)
        all_embeddings.append(padded_embedding)
    
    return all_embeddings

# %%
document_contents = [doc.page_content for doc in documents]
x = extract_embeddings(document_contents)

# %%
x
# Out:
# [array([-4.55150567e-02, -1.97336376e-02,  1.25892535e-02, -4.55243140e-02,
#         -2.90939808e-02, -2.95742527e-02,  3.13913152e-02, -4.86487299e-02,
#         -2.19278261e-02, -5.63519187e-02, -3.02891266e-02, -2.15906538e-02,
#          4.19987664e-02, -2.08945181e-02,  9.25024226e-03, -3.97202075e-02,
#          3.10281236e-02, -1.05627380e-01, -6.95655271e-02, -4.94096167e-02,
#         -4.29455703e-03, -2.19773538e-02, -3.98334712e-02, -5.22820950e-02,
#         -7.61642382e-02,  4.95978519e-02,  7.92976841e-03, -5.70645593e-02,
#          1.49083231e-02,  2.63484027e-02,  4.89106737e-02,  1.44885182e-02,
#          1.43559426e-01, -5.34537919e-02, -1.02815971e-01,  2.76076365e-02,
#         -1.76116470e-02, -7.46346544e-03,  3.00797857e-02, -3.15535553e-02,
#         -6.05688803e-02, -1.00552231e-01,  3.69214849e-03,  3.41370702e-02,
#          6.23851418e-02,  1.19003179e-02, -1.20642260e-01, -4.39265780e-02,
#          9.43379924e-02,  5.47228381e-02, -5.14179990e-02, -7.97651149e-03,
#          1.09546207e-01, -2.19050404e-02, -5.20362854e-02,  5.35327084e-02,
#         -3.55544761e-02,  3.00971176e-02,  8.91510844e-02, -5.21156117e-02,
#          3.66447195e-02, -1.10446929e-03,  1.32019341e-01,  5.61789498e-02,
#          6.93384111e-02, -2.30616499e-02, -4.23622876e-02, -8.01903680e-02,
#          3.57802995e-02, -1.13833480e-01,  6.54689455e-03,  4.20076922e-02,
#         -4.38692793e-02, -2.08129622e-02,  1.41212046e-02, -1.87920034e-03,
-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00])]

# %% [markdown]
# # Inserting into VDB

# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec

# %%
pc_api_key = "9bf699ce-092d-48a9-8526-a219a8e3d509"
pc = Pinecone(api_key=pc_api_key)

# %%
pc.create_index(
    name="fyp-txt-embed",
    dimension=384,  
    metric="dotproduct", 
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)

# %%
index = pc.Index(name="fyp-txt-embed")

# %%
index

# %%
# Get embeddings for each document
document_contents = [doc.page_content for doc in documents]
embeddings_list = [embeddings.embed_query(text) for text in document_contents]

# Prepare data for upsert: List of tuples (id, vector, metadata)
values = [
    (str(i), emb, {"text": document_contents[i]})  # Convert embedding to list format
    for i, emb in enumerate(embeddings_list)
]

# %%
index.upsert(vectors=values)
# Out:
# {'upserted_count': 4}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 4}},
#  'total_vector_count': 4}

# %% [markdown]
# # Query

# %%
# Define your query text
query_text = "AI development challenges in human-computer interaction"

# Generate the embedding for the query
query_embedding = embeddings.embed_query(query_text)

# Perform the query on the Pinecone index
response = index.query(
    vector=query_embedding,
    top_k=5,  # Number of closest vectors to return
    include_values=True,  # Include the vectors themselves
    include_metadata=True  # Include the metadata (like original text)
)

# Display the results
for match in response["matches"]:
    print(f"ID: {match['id']}")
    print(f"Score: {match['score']}")
    print(f"Metadata: {match['metadata']}\n")
# Out:
# ID: 2
# Score: 0.687274337
# Metadata: {'text': 'The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX. Modern AI development tends to be technology-driven, therefore UX is not attended optimally. HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed.'}
#
# ID: 1
# Score: 0.655767143
# Metadata: {'text': 'The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions. This thesis research discusses issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making, and addressing automation bias, which occurs when people over trust and blindly embrace computer-based assistance. The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.'}
#
# ID: 0
# Score: 0.640099406
# Metadata: {'text': 'The rapid advancements in artificial intelligence (AI) bring benefits and problems to user interface (UI) design. Human-Computer Interaction(HCI) concept has been a fundamental part of human and AI interaction for more than two decades given the advancement of AI and its growing applications in human-centric fields. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions.'}
#
# ID: 3
# Score: 0.613109529
# Metadata: {'text': 'HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed. HCAI has lately surfaced as a trend however, there is still work to be done to reduce the remaining gap which is only possible by its widespread acceptance.The objective of the research was to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys. The findings of the paper investigate collaborative intelligence and ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.Keywords: Human-Computer Interaction, Artificial Intelligence, User Interface, User Experience, AI-driven Interfaces, Human-centered AI, Users, Pakistan'}

# %% [markdown]
# # LLM - GROQ

# %%
from groq import Groq
from langchain_groq import ChatGroq

# %%
groq_api_key = "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"

# %%
llm = ChatGroq(
    model="mixtral-8x7b-32768",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key= groq_api_key,
)
print("GROQ LLM loaded")
# Out:
# GROQ LLM loaded

# %% [markdown]
# # QA Chain

# %%
# !pip install -U langchain-pinecone
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.1.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.5 in /opt/conda/lib/python3.10/site-packages (from langchain-pinecone) (3.9.5)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /opt/conda/lib/python3.10/site-packages (from langchain-pinecone) (0.2.39)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain-pinecone) (1.26.4)
# Requirement already satisfied: pinecone-client<6.0.0,>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain-pinecone) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.1.117)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (8.3.0)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (4.12.2)
# Requirement already satisfied: certifi>=2019.11.17 in /opt/conda/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (2024.7.4)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /opt/conda/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (1.0.3)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: tqdm>=4.64.1 in /opt/conda/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (4.66.4)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (1.26.18)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (3.10.4)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.20.1)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (3.7)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.1.52->langchain-pinecone) (1.2.0)
# Downloading langchain_pinecone-0.1.3-py3-none-any.whl (10 kB)
# Installing collected packages: langchain-pinecone
# Successfully installed langchain-pinecone-0.1.3

# %%
from langchain.prompts import PromptTemplate

# Define the prompt template
prompt_template = """The following is a conversation with an AI assistant.
The assistant is helpful, creative, clever, and very friendly.

Relevant Document: {context}

User: {question}
AI:"""

PROMPT = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)

# %%
from langchain_pinecone import Pinecone
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain import PromptTemplate, LLMChain
from langchain.chains import RetrievalQA
from langchain.memory import ConversationBufferMemory
import pinecone

# %%
from pinecone import Pinecone, ServerlessSpec
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain import PromptTemplate, LLMChain
from langchain.chains import RetrievalQA
from langchain.memory import ConversationBufferMemory
from langchain_pinecone import Pinecone as LangchainPinecone

# %%
memory = ConversationBufferMemory(memory_key="chat_history", output_key="answer")

# %%
vectordb = PineconeVectorStore(index=index, embedding=embeddings.embed_query, text_key="text")
vectorstore=vectordb.as_retriever(search_type="similarity", search_kwargs={'k': 5})
# custom_retriever = CustomRetriever(
#     vectorstore=vectordb.as_retriever(search_type="similarity", search_kwargs={'k': 5})
# )

# %%
qa_chain = RetrievalQA.from_chain_type(
            llm=llm,
            chain_type="stuff",
            retriever=vectorstore,
            return_source_documents=True,
            chain_type_kwargs={"prompt": PROMPT},
            memory=memory,
            output_key="answer"
        )

# %%
qa_chain({"query":"what are the main points in the text"})
# Out:
# /tmp/ipykernel_36/1162479717.py:1: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   qa_chain({"query":"what are the main points in the text"})
# {'query': 'what are the main points in the text',
#  'chat_history': '',
#  'answer': 'The main points in the text are:\n\n1. The text discusses the importance of integrating Human-Computer Interaction (HCI) concepts into the development of AI interfaces to improve User Experience (UX).\n2. The advancement of AI and its growing applications in human-centric fields have made HCI a fundamental part of human and AI interaction for more than two decades.\n3. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved UX interactions.\n4. The text identifies issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making and automation bias, which occurs when people over-trust and blindly embrace computer-based assistance.\n5. The research aims to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys.\n6. The paper focuses on ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.\n7. The text presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.\n8. The text highlights that HCAI has recently emerged as a trend, but there is still a need for the gap between technology-driven AI development and user-centered HCAI to be closed.',
#  'source_documents': [Document(page_content='The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX. Modern AI development tends to be technology-driven, therefore UX is not attended optimally. HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed.'),
#   Document(page_content='HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed. HCAI has lately surfaced as a trend however, there is still work to be done to reduce the remaining gap which is only possible by its widespread acceptance.The objective of the research was to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys. The findings of the paper investigate collaborative intelligence and ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.Keywords: Human-Computer Interaction, Artificial Intelligence, User Interface, User Experience, AI-driven Interfaces, Human-centered AI, Users, Pakistan'),
#   Document(page_content='The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions. This thesis research discusses issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making, and addressing automation bias, which occurs when people over trust and blindly embrace computer-based assistance. The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.'),
#   Document(page_content='The rapid advancements in artificial intelligence (AI) bring benefits and problems to user interface (UI) design. Human-Computer Interaction(HCI) concept has been a fundamental part of human and AI interaction for more than two decades given the advancement of AI and its growing applications in human-centric fields. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions.')]}

# %%
qa_chain({"query":"what is the importance of HCI"})
# Out:
# {'query': 'what is the importance of HCI',
#  'chat_history': 'Human: what are the main points in the text\nAI: The main points in the text are:\n\n1. The text discusses the importance of integrating Human-Computer Interaction (HCI) concepts into the development of AI interfaces to improve User Experience (UX).\n2. The advancement of AI and its growing applications in human-centric fields have made HCI a fundamental part of human and AI interaction for more than two decades.\n3. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved UX interactions.\n4. The text identifies issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making and automation bias, which occurs when people over-trust and blindly embrace computer-based assistance.\n5. The research aims to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys.\n6. The paper focuses on ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.\n7. The text presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.\n8. The text highlights that HCAI has recently emerged as a trend, but there is still a need for the gap between technology-driven AI development and user-centered HCAI to be closed.',
#  'answer': 'Human-Computer Interaction (HCI) is of great importance in the context of AI development for several reasons. \n\nFirstly, HCI helps to ensure that AI systems are designed with the user in mind. This is crucial because AI systems can be quite complex, and if they are not designed with user experience in mind, they can be difficult for users to interact with. HCI helps to make these systems more intuitive and user-friendly.\n\nSecondly, HCI can help to reduce automation bias. This is a phenomenon where people tend to over-trust and blindly embrace computer-based assistance. HCI can help to design AI systems in such a way that they complement human decision-making, rather than replacing it.\n\nThirdly, HCI is important in the context of AI because it can help to ensure that these systems are used ethically and responsibly. By involving users in the design process, HCI can help to ensure that AI systems are designed in a way that respects user privacy and autonomy.\n\nIn the context of your research, the importance of HCI lies in its ability to improve user experience (UX) interactions in AI interfaces. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) can lead to improved UX, which is crucial given that modern AI development tends to be technology-driven and UX is not always optimally attended to. The research you mentioned also focuses on identifying and understanding the nature of AI interfaces in practice, with a focus on incorporating the HCI concept into the development of AI-driven applications, especially in the Pakistani context.',
#  'source_documents': [Document(page_content='The rapid advancements in artificial intelligence (AI) bring benefits and problems to user interface (UI) design. Human-Computer Interaction(HCI) concept has been a fundamental part of human and AI interaction for more than two decades given the advancement of AI and its growing applications in human-centric fields. The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions.'),
#   Document(page_content='HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed. HCAI has lately surfaced as a trend however, there is still work to be done to reduce the remaining gap which is only possible by its widespread acceptance.The objective of the research was to identify and understand the nature of AI interfaces in practice by conducting interviews and surveys. The findings of the paper investigate collaborative intelligence and ways for Pakistani enterprises to capitalize on AI capabilities, with a focus on incorporating the HCI concept into the development of AI-driven applications.Keywords: Human-Computer Interaction, Artificial Intelligence, User Interface, User Experience, AI-driven Interfaces, Human-centered AI, Users, Pakistan'),
#   Document(page_content='The consolidation of AI with HCI design and Human-Centered Artificial Intelligence (HCAI) offers improved User experience (UX) interactions. This thesis research discusses issues in implementing HCI in the development of AI interfaces, including algorithmic decision-making, and addressing automation bias, which occurs when people over trust and blindly embrace computer-based assistance. The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX.'),
#   Document(page_content='The thesis also presents an assessment of the current state of human-centered AI difficulties encountered by Pakistani developers and proposes solutions to improve UX. Modern AI development tends to be technology-driven, therefore UX is not attended optimally. HCAI has recently emerged as a trend though there is still a need for the further gap between them to be closed.')]}

# %%
def get_output():
    from huggingface_hub import InferenceClient

    client = InferenceClient(api_key="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")

    messages = [
        {
            "role": "system",
            "content": "You are a friendly chatbot who always has a positive attitude. You are here to help customers with their questions. Please keep your answer brief and relevant. If the text is not applicable to the question, reply with 'Not applicable.' If you dont find the answer to my question in the given context, just say 'Not Applicable'. You need to provide an answer based on the following content: "
        },
        {
            "role": "user",
            "content": query_text
        }
    ]

    completion = client.chat.completions.create(
        model="HuggingFaceTB/SmolLM2-1.7B-Instruct", 
        messages=messages, 
        max_tokens=500
    )

    print(completion.choices[0].message)
# Out:
# ChatCompletionOutputMessage(role='assistant', content="The capital of France is Paris. Paris is known for its historical landmarks, culture, gastronomy, fashion, and art. It's a major European city and one of the most important cities in the world, known for its iconic Eiffel Tower, Louvre Museum, and Notre-Dame Cathedral.", tool_calls=None)
